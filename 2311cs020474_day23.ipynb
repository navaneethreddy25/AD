# %% [markdown]
# <a href="https://colab.research.google.com/github/navaneethreddy25/AD/blob/main/2311cs020474_day23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
# Out:
#      <input type="file" id="files-a743eb30-43ad-403c-8ff3-d5fc045a6b71" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a743eb30-43ad-403c-8ff3-d5fc045a6b71">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cars = pd.read_csv('Cars.csv')
cars.head()
# Out:
#    HP        MPG  VOL          SP           WT
# 0  49  53.700681   89  104.185353   28.7620589
# 1  55  50.013401   92  105.461264  30.46683298
# 2  55  50.013401   92  105.461264  30.19359657
# 3  70  45.696322   92  113.461264  30.63211391
# 4  53  50.504232   92  104.461264  29.88914864

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


data = np.random.normal(loc=0, scale=1, size=1000)
df = pd.DataFrame({'Value': data})


sns.histplot(data=df, x='Value', kde=True)
plt.title('Distribution of Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

sns.boxplot(data=df, y='Value')
plt.title('Box Plot of Data')
plt.ylabel('Value')
plt.show()


sns.violinplot(data=df, y='Value')
plt.title('Violin Plot of Data')
plt.ylabel('Value')
plt.show()

# %%
sns.scatterplot(data=df, y='Value')
plt.title('scatter plot of Data')
plt.ylabel('Value')
plt.show()
